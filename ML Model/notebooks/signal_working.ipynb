# %%
import time

def traffic_signal():
    # Define the directions and their respective durations in seconds
    directions = [
        {"name": "North", "duration": 10},
        {"name": "East", "duration": 10},
        {"name": "South", "duration": 10},
        {"name": "West", "duration": 10}
    ]

    while True:
        for i, direction in enumerate(directions):
            for t in range(direction["duration"], 0, -1):
                # Clear the console for dynamic updates (optional for better visualization)
                print("\033[H\033[J", end="")  # ANSI escape sequence to clear screen

                # Display the traffic signal status
                print("Traffic Signal Status:")
                for j, d in enumerate(directions):
                    if d["name"] == direction["name"]:
                        print(f"{d['name']}: GREEN ({t} seconds left)")
                    else:
                        # Calculate the waiting time based on the current position and the cycle
                        cycle_offset = (j - i - 1) % len(directions)
                        remaining_time = sum(directions[(i + 1 + k) % len(directions)]["duration"] for k in range(cycle_offset))
                        print(f"{d['name']}: RED (Waiting: {remaining_time + t} seconds)")

                # Wait for 1 second
                time.sleep(1)

if __name__ == "__main__":
    try:
        traffic_signal()
    except KeyboardInterrupt:
        print("\nTraffic signal simulation ended.")
# Out:
# Traffic Signal Status:
# North: GREEN (10 seconds left)
# East: RED (Waiting: 10 seconds)
# South: RED (Waiting: 20 seconds)
# West: RED (Waiting: 30 seconds)
# Traffic Signal Status:
# North: GREEN (9 seconds left)
# East: RED (Waiting: 9 seconds)
# South: RED (Waiting: 19 seconds)
# West: RED (Waiting: 29 seconds)
# Traffic Signal Status:
# North: GREEN (8 seconds left)
# East: RED (Waiting: 8 seconds)
# South: RED (Waiting: 18 seconds)
# West: RED (Waiting: 28 seconds)
# Traffic Signal Status:
# North: GREEN (7 seconds left)
# East: RED (Waiting: 7 seconds)
# South: RED (Waiting: 17 seconds)
# West: RED (Waiting: 27 seconds)
# Traffic Signal Status:
# North: GREEN (6 seconds left)
# East: RED (Waiting: 6 seconds)
# South: RED (Waiting: 16 seconds)
# West: RED (Waiting: 26 seconds)
# Traffic Signal Status:
# North: GREEN (5 seconds left)
# East: RED (Waiting: 5 seconds)
# South: RED (Waiting: 15 seconds)
# West: RED (Waiting: 25 seconds)
# Traffic Signal Status:
# North: GREEN (4 seconds left)
# East: RED (Waiting: 4 seconds)
# South: RED (Waiting: 14 seconds)
# West: RED (Waiting: 24 seconds)
# Traffic Signal Status:
# North: GREEN (3 seconds left)
# East: RED (Waiting: 3 seconds)
# South: RED (Waiting: 13 seconds)
# West: RED (Waiting: 23 seconds)
# Traffic Signal Status:
# North: GREEN (2 seconds left)
# East: RED (Waiting: 2 seconds)
# South: RED (Waiting: 12 seconds)
# West: RED (Waiting: 22 seconds)
# Traffic Signal Status:
# North: GREEN (1 seconds left)
# East: RED (Waiting: 1 seconds)
# South: RED (Waiting: 11 seconds)
# West: RED (Waiting: 21 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 30 seconds)
# East: GREEN (10 seconds left)
# South: RED (Waiting: 10 seconds)
# West: RED (Waiting: 20 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 29 seconds)
# East: GREEN (9 seconds left)
# South: RED (Waiting: 9 seconds)
# West: RED (Waiting: 19 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 28 seconds)
# East: GREEN (8 seconds left)
# South: RED (Waiting: 8 seconds)
# West: RED (Waiting: 18 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 27 seconds)
# East: GREEN (7 seconds left)
# South: RED (Waiting: 7 seconds)
# West: RED (Waiting: 17 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 26 seconds)
# East: GREEN (6 seconds left)
# South: RED (Waiting: 6 seconds)
# West: RED (Waiting: 16 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 25 seconds)
# East: GREEN (5 seconds left)
# South: RED (Waiting: 5 seconds)
# West: RED (Waiting: 15 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 24 seconds)
# East: GREEN (4 seconds left)
# South: RED (Waiting: 4 seconds)
# West: RED (Waiting: 14 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 23 seconds)
# East: GREEN (3 seconds left)
# South: RED (Waiting: 3 seconds)
# West: RED (Waiting: 13 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 22 seconds)
# East: GREEN (2 seconds left)
# South: RED (Waiting: 2 seconds)
# West: RED (Waiting: 12 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 21 seconds)
# East: GREEN (1 seconds left)
# South: RED (Waiting: 1 seconds)
# West: RED (Waiting: 11 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 20 seconds)
# East: RED (Waiting: 30 seconds)
# South: GREEN (10 seconds left)
# West: RED (Waiting: 10 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 19 seconds)
# East: RED (Waiting: 29 seconds)
# South: GREEN (9 seconds left)
# West: RED (Waiting: 9 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 18 seconds)
# East: RED (Waiting: 28 seconds)
# South: GREEN (8 seconds left)
# West: RED (Waiting: 8 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 17 seconds)
# East: RED (Waiting: 27 seconds)
# South: GREEN (7 seconds left)
# West: RED (Waiting: 7 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 16 seconds)
# East: RED (Waiting: 26 seconds)
# South: GREEN (6 seconds left)
# West: RED (Waiting: 6 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 15 seconds)
# East: RED (Waiting: 25 seconds)
# South: GREEN (5 seconds left)
# West: RED (Waiting: 5 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 14 seconds)
# East: RED (Waiting: 24 seconds)
# South: GREEN (4 seconds left)
# West: RED (Waiting: 4 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 13 seconds)
# East: RED (Waiting: 23 seconds)
# South: GREEN (3 seconds left)
# West: RED (Waiting: 3 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 12 seconds)
# East: RED (Waiting: 22 seconds)
# South: GREEN (2 seconds left)
# West: RED (Waiting: 2 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 11 seconds)
# East: RED (Waiting: 21 seconds)
# South: GREEN (1 seconds left)
# West: RED (Waiting: 1 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 10 seconds)
# East: RED (Waiting: 20 seconds)
# South: RED (Waiting: 30 seconds)
# West: GREEN (10 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 9 seconds)
# East: RED (Waiting: 19 seconds)
# South: RED (Waiting: 29 seconds)
# West: GREEN (9 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 8 seconds)
# East: RED (Waiting: 18 seconds)
# South: RED (Waiting: 28 seconds)
# West: GREEN (8 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 7 seconds)
# East: RED (Waiting: 17 seconds)
# South: RED (Waiting: 27 seconds)
# West: GREEN (7 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 6 seconds)
# East: RED (Waiting: 16 seconds)
# South: RED (Waiting: 26 seconds)
# West: GREEN (6 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 5 seconds)
# East: RED (Waiting: 15 seconds)
# South: RED (Waiting: 25 seconds)
# West: GREEN (5 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 4 seconds)
# East: RED (Waiting: 14 seconds)
# South: RED (Waiting: 24 seconds)
# West: GREEN (4 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 3 seconds)
# East: RED (Waiting: 13 seconds)
# South: RED (Waiting: 23 seconds)
# West: GREEN (3 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 2 seconds)
# East: RED (Waiting: 12 seconds)
# South: RED (Waiting: 22 seconds)
# West: GREEN (2 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 1 seconds)
# East: RED (Waiting: 11 seconds)
# South: RED (Waiting: 21 seconds)
# West: GREEN (1 seconds left)
# Traffic Signal Status:
# North: GREEN (10 seconds left)
# East: RED (Waiting: 10 seconds)
# South: RED (Waiting: 20 seconds)
# West: RED (Waiting: 30 seconds)
# Traffic Signal Status:
# North: GREEN (9 seconds left)
# East: RED (Waiting: 9 seconds)
# South: RED (Waiting: 19 seconds)
# West: RED (Waiting: 29 seconds)
# Traffic Signal Status:
# North: GREEN (8 seconds left)
# East: RED (Waiting: 8 seconds)
# South: RED (Waiting: 18 seconds)
# West: RED (Waiting: 28 seconds)
# Traffic Signal Status:
# North: GREEN (7 seconds left)
# East: RED (Waiting: 7 seconds)
# South: RED (Waiting: 17 seconds)
# West: RED (Waiting: 27 seconds)
# Traffic Signal Status:
# North: GREEN (6 seconds left)
# East: RED (Waiting: 6 seconds)
# South: RED (Waiting: 16 seconds)
# West: RED (Waiting: 26 seconds)
# Traffic Signal Status:
# North: GREEN (5 seconds left)
# East: RED (Waiting: 5 seconds)
# South: RED (Waiting: 15 seconds)
# West: RED (Waiting: 25 seconds)
# Traffic Signal Status:
# North: GREEN (4 seconds left)
# East: RED (Waiting: 4 seconds)
# South: RED (Waiting: 14 seconds)
# West: RED (Waiting: 24 seconds)
# Traffic Signal Status:
# North: GREEN (3 seconds left)
# East: RED (Waiting: 3 seconds)
# South: RED (Waiting: 13 seconds)
# West: RED (Waiting: 23 seconds)
# Traffic Signal Status:
# North: GREEN (2 seconds left)
# East: RED (Waiting: 2 seconds)
# South: RED (Waiting: 12 seconds)
# West: RED (Waiting: 22 seconds)
# Traffic Signal Status:
# North: GREEN (1 seconds left)
# East: RED (Waiting: 1 seconds)
# South: RED (Waiting: 11 seconds)
# West: RED (Waiting: 21 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 30 seconds)
# East: GREEN (10 seconds left)
# South: RED (Waiting: 10 seconds)
# West: RED (Waiting: 20 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 29 seconds)
# East: GREEN (9 seconds left)
# South: RED (Waiting: 9 seconds)
# West: RED (Waiting: 19 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 28 seconds)
# East: GREEN (8 seconds left)
# South: RED (Waiting: 8 seconds)
# West: RED (Waiting: 18 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 27 seconds)
# East: GREEN (7 seconds left)
# South: RED (Waiting: 7 seconds)
# West: RED (Waiting: 17 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 26 seconds)
# East: GREEN (6 seconds left)
# South: RED (Waiting: 6 seconds)
# West: RED (Waiting: 16 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 25 seconds)
# East: GREEN (5 seconds left)
# South: RED (Waiting: 5 seconds)
# West: RED (Waiting: 15 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 24 seconds)
# East: GREEN (4 seconds left)
# South: RED (Waiting: 4 seconds)
# West: RED (Waiting: 14 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 23 seconds)
# East: GREEN (3 seconds left)
# South: RED (Waiting: 3 seconds)
# West: RED (Waiting: 13 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 22 seconds)
# East: GREEN (2 seconds left)
# South: RED (Waiting: 2 seconds)
# West: RED (Waiting: 12 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 21 seconds)
# East: GREEN (1 seconds left)
# South: RED (Waiting: 1 seconds)
# West: RED (Waiting: 11 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 20 seconds)
# East: RED (Waiting: 30 seconds)
# South: GREEN (10 seconds left)
# West: RED (Waiting: 10 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 19 seconds)
# East: RED (Waiting: 29 seconds)
# South: GREEN (9 seconds left)
# West: RED (Waiting: 9 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 18 seconds)
# East: RED (Waiting: 28 seconds)
# South: GREEN (8 seconds left)
# West: RED (Waiting: 8 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 17 seconds)
# East: RED (Waiting: 27 seconds)
# South: GREEN (7 seconds left)
# West: RED (Waiting: 7 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 16 seconds)
# East: RED (Waiting: 26 seconds)
# South: GREEN (6 seconds left)
# West: RED (Waiting: 6 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 15 seconds)
# East: RED (Waiting: 25 seconds)
# South: GREEN (5 seconds left)
# West: RED (Waiting: 5 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 14 seconds)
# East: RED (Waiting: 24 seconds)
# South: GREEN (4 seconds left)
# West: RED (Waiting: 4 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 13 seconds)
# East: RED (Waiting: 23 seconds)
# South: GREEN (3 seconds left)
# West: RED (Waiting: 3 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 12 seconds)
# East: RED (Waiting: 22 seconds)
# South: GREEN (2 seconds left)
# West: RED (Waiting: 2 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 11 seconds)
# East: RED (Waiting: 21 seconds)
# South: GREEN (1 seconds left)
# West: RED (Waiting: 1 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 10 seconds)
# East: RED (Waiting: 20 seconds)
# South: RED (Waiting: 30 seconds)
# West: GREEN (10 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 9 seconds)
# East: RED (Waiting: 19 seconds)
# South: RED (Waiting: 29 seconds)
# West: GREEN (9 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 8 seconds)
# East: RED (Waiting: 18 seconds)
# South: RED (Waiting: 28 seconds)
# West: GREEN (8 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 7 seconds)
# East: RED (Waiting: 17 seconds)
# South: RED (Waiting: 27 seconds)
# West: GREEN (7 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 6 seconds)
# East: RED (Waiting: 16 seconds)
# South: RED (Waiting: 26 seconds)
# West: GREEN (6 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 5 seconds)
# East: RED (Waiting: 15 seconds)
# South: RED (Waiting: 25 seconds)
# West: GREEN (5 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 4 seconds)
# East: RED (Waiting: 14 seconds)
# South: RED (Waiting: 24 seconds)
# West: GREEN (4 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 3 seconds)
# East: RED (Waiting: 13 seconds)
# South: RED (Waiting: 23 seconds)
# West: GREEN (3 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 2 seconds)
# East: RED (Waiting: 12 seconds)
# South: RED (Waiting: 22 seconds)
# West: GREEN (2 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 1 seconds)
# East: RED (Waiting: 11 seconds)
# South: RED (Waiting: 21 seconds)
# West: GREEN (1 seconds left)
# Traffic Signal Status:
# North: GREEN (10 seconds left)
# East: RED (Waiting: 10 seconds)
# South: RED (Waiting: 20 seconds)
# West: RED (Waiting: 30 seconds)
# Traffic Signal Status:
# North: GREEN (9 seconds left)
# East: RED (Waiting: 9 seconds)
# South: RED (Waiting: 19 seconds)
# West: RED (Waiting: 29 seconds)
# Traffic Signal Status:
# North: GREEN (8 seconds left)
# East: RED (Waiting: 8 seconds)
# South: RED (Waiting: 18 seconds)
# West: RED (Waiting: 28 seconds)
# Traffic Signal Status:
# North: GREEN (7 seconds left)
# East: RED (Waiting: 7 seconds)
# South: RED (Waiting: 17 seconds)
# West: RED (Waiting: 27 seconds)
# Traffic Signal Status:
# North: GREEN (6 seconds left)
# East: RED (Waiting: 6 seconds)
# South: RED (Waiting: 16 seconds)
# West: RED (Waiting: 26 seconds)
# Traffic Signal Status:
# North: GREEN (5 seconds left)
# East: RED (Waiting: 5 seconds)
# South: RED (Waiting: 15 seconds)
# West: RED (Waiting: 25 seconds)
# Traffic Signal Status:
# North: GREEN (4 seconds left)
# East: RED (Waiting: 4 seconds)
# South: RED (Waiting: 14 seconds)
# West: RED (Waiting: 24 seconds)
# Traffic Signal Status:
# North: GREEN (3 seconds left)
# East: RED (Waiting: 3 seconds)
# South: RED (Waiting: 13 seconds)
# West: RED (Waiting: 23 seconds)
# Traffic Signal Status:
# North: GREEN (2 seconds left)
# East: RED (Waiting: 2 seconds)
# South: RED (Waiting: 12 seconds)
# West: RED (Waiting: 22 seconds)
# Traffic Signal Status:
# North: GREEN (1 seconds left)
# East: RED (Waiting: 1 seconds)
# South: RED (Waiting: 11 seconds)
# West: RED (Waiting: 21 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 30 seconds)
# East: GREEN (10 seconds left)
# South: RED (Waiting: 10 seconds)
# West: RED (Waiting: 20 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 29 seconds)
# East: GREEN (9 seconds left)
# South: RED (Waiting: 9 seconds)
# West: RED (Waiting: 19 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 28 seconds)
# East: GREEN (8 seconds left)
# South: RED (Waiting: 8 seconds)
# West: RED (Waiting: 18 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 27 seconds)
# East: GREEN (7 seconds left)
# South: RED (Waiting: 7 seconds)
# West: RED (Waiting: 17 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 26 seconds)
# East: GREEN (6 seconds left)
# South: RED (Waiting: 6 seconds)
# West: RED (Waiting: 16 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 25 seconds)
# East: GREEN (5 seconds left)
# South: RED (Waiting: 5 seconds)
# West: RED (Waiting: 15 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 24 seconds)
# East: GREEN (4 seconds left)
# South: RED (Waiting: 4 seconds)
# West: RED (Waiting: 14 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 23 seconds)
# East: GREEN (3 seconds left)
# South: RED (Waiting: 3 seconds)
# West: RED (Waiting: 13 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 22 seconds)
# East: GREEN (2 seconds left)
# South: RED (Waiting: 2 seconds)
# West: RED (Waiting: 12 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 21 seconds)
# East: GREEN (1 seconds left)
# South: RED (Waiting: 1 seconds)
# West: RED (Waiting: 11 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 20 seconds)
# East: RED (Waiting: 30 seconds)
# South: GREEN (10 seconds left)
# West: RED (Waiting: 10 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 19 seconds)
# East: RED (Waiting: 29 seconds)
# South: GREEN (9 seconds left)
# West: RED (Waiting: 9 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 18 seconds)
# East: RED (Waiting: 28 seconds)
# South: GREEN (8 seconds left)
# West: RED (Waiting: 8 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 17 seconds)
# East: RED (Waiting: 27 seconds)
# South: GREEN (7 seconds left)
# West: RED (Waiting: 7 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 16 seconds)
# East: RED (Waiting: 26 seconds)
# South: GREEN (6 seconds left)
# West: RED (Waiting: 6 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 15 seconds)
# East: RED (Waiting: 25 seconds)
# South: GREEN (5 seconds left)
# West: RED (Waiting: 5 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 14 seconds)
# East: RED (Waiting: 24 seconds)
# South: GREEN (4 seconds left)
# West: RED (Waiting: 4 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 13 seconds)
# East: RED (Waiting: 23 seconds)
# South: GREEN (3 seconds left)
# West: RED (Waiting: 3 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 12 seconds)
# East: RED (Waiting: 22 seconds)
# South: GREEN (2 seconds left)
# West: RED (Waiting: 2 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 11 seconds)
# East: RED (Waiting: 21 seconds)
# South: GREEN (1 seconds left)
# West: RED (Waiting: 1 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 10 seconds)
# East: RED (Waiting: 20 seconds)
# South: RED (Waiting: 30 seconds)
# West: GREEN (10 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 9 seconds)
# East: RED (Waiting: 19 seconds)
# South: RED (Waiting: 29 seconds)
# West: GREEN (9 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 8 seconds)
# East: RED (Waiting: 18 seconds)
# South: RED (Waiting: 28 seconds)
# West: GREEN (8 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 7 seconds)
# East: RED (Waiting: 17 seconds)
# South: RED (Waiting: 27 seconds)
# West: GREEN (7 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 6 seconds)
# East: RED (Waiting: 16 seconds)
# South: RED (Waiting: 26 seconds)
# West: GREEN (6 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 5 seconds)
# East: RED (Waiting: 15 seconds)
# South: RED (Waiting: 25 seconds)
# West: GREEN (5 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 4 seconds)
# East: RED (Waiting: 14 seconds)
# South: RED (Waiting: 24 seconds)
# West: GREEN (4 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 3 seconds)
# East: RED (Waiting: 13 seconds)
# South: RED (Waiting: 23 seconds)
# West: GREEN (3 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 2 seconds)
# East: RED (Waiting: 12 seconds)
# South: RED (Waiting: 22 seconds)
# West: GREEN (2 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 1 seconds)
# East: RED (Waiting: 11 seconds)
# South: RED (Waiting: 21 seconds)
# West: GREEN (1 seconds left)
# Traffic Signal Status:
# North: GREEN (10 seconds left)
# East: RED (Waiting: 10 seconds)
# South: RED (Waiting: 20 seconds)
# West: RED (Waiting: 30 seconds)
# Traffic Signal Status:
# North: GREEN (9 seconds left)
# East: RED (Waiting: 9 seconds)
# South: RED (Waiting: 19 seconds)
# West: RED (Waiting: 29 seconds)
# Traffic Signal Status:
# North: GREEN (8 seconds left)
# East: RED (Waiting: 8 seconds)
# South: RED (Waiting: 18 seconds)
# West: RED (Waiting: 28 seconds)
# Traffic Signal Status:
# North: GREEN (7 seconds left)
# East: RED (Waiting: 7 seconds)
# South: RED (Waiting: 17 seconds)
# West: RED (Waiting: 27 seconds)
# Traffic Signal Status:
# North: GREEN (6 seconds left)
# East: RED (Waiting: 6 seconds)
# South: RED (Waiting: 16 seconds)
# West: RED (Waiting: 26 seconds)
# Traffic Signal Status:
# North: GREEN (5 seconds left)
# East: RED (Waiting: 5 seconds)
# South: RED (Waiting: 15 seconds)
# West: RED (Waiting: 25 seconds)
#
# Traffic signal simulation ended.

# %%
#Implementation of basic traffic simulation with red, orange and green times
import time

def traffic_signal():
    # Define the directions and their respective durations in seconds
    directions = [
        {"name": "North", "duration": 10},
        {"name": "East", "duration": 10},
        {"name": "South", "duration": 10},
        {"name": "West", "duration": 10}
    ]

    orange_duration = 3  # Duration for the orange signal

    while True:
        for i, direction in enumerate(directions):
            # Handle green signal
            for t in range(direction["duration"], 0, -1):
                # Clear the console for dynamic updates (optional for better visualization)
                print("\033[H\033[J", end="")  # ANSI escape sequence to clear screen

                # Display the traffic signal status
                print("Traffic Signal Status:")
                for j, d in enumerate(directions):
                    if d["name"] == direction["name"]:
                        print(f"{d['name']}: GREEN ({t} seconds left)")
                    else:
                        # Calculate the waiting time based on the current position and the cycle
                        cycle_offset = (j - i - 1) % len(directions)
                        remaining_time = sum(directions[(i + 1 + k) % len(directions)]["duration"] for k in range(cycle_offset)) + orange_duration
                        print(f"{d['name']}: RED (Waiting: {remaining_time + t} seconds)")

                # Wait for 1 second
                time.sleep(1)

            # Handle orange signal
            for t in range(orange_duration, 0, -1):
                # Clear the console for dynamic updates (optional for better visualization)
                print("\033[H\033[J", end="")  # ANSI escape sequence to clear screen

                # Display the traffic signal status
                print("Traffic Signal Status:")
                for j, d in enumerate(directions):
                    if d["name"] == direction["name"]:
                        print(f"{d['name']}: ORANGE ({t} seconds left)")
                    else:
                        # Calculate the waiting time based on the current position and the cycle
                        cycle_offset = (j - i - 1) % len(directions)
                        remaining_time = sum(directions[(i + 1 + k) % len(directions)]["duration"] for k in range(cycle_offset)) + orange_duration
                        print(f"{d['name']}: RED (Waiting: {remaining_time + t - orange_duration} seconds)")

                # Wait for 1 second
                time.sleep(1)

if __name__ == "__main__":
    try:
        traffic_signal()
    except KeyboardInterrupt:
        print("\nTraffic signal simulation ended.")
# Out:
# Traffic Signal Status:
# North: GREEN (10 seconds left)
# East: RED (Waiting: 13 seconds)
# South: RED (Waiting: 23 seconds)
# West: RED (Waiting: 33 seconds)
# Traffic Signal Status:
# North: GREEN (9 seconds left)
# East: RED (Waiting: 12 seconds)
# South: RED (Waiting: 22 seconds)
# West: RED (Waiting: 32 seconds)
# Traffic Signal Status:
# North: GREEN (8 seconds left)
# East: RED (Waiting: 11 seconds)
# South: RED (Waiting: 21 seconds)
# West: RED (Waiting: 31 seconds)
# Traffic Signal Status:
# North: GREEN (7 seconds left)
# East: RED (Waiting: 10 seconds)
# South: RED (Waiting: 20 seconds)
# West: RED (Waiting: 30 seconds)
# Traffic Signal Status:
# North: GREEN (6 seconds left)
# East: RED (Waiting: 9 seconds)
# South: RED (Waiting: 19 seconds)
# West: RED (Waiting: 29 seconds)
# Traffic Signal Status:
# North: GREEN (5 seconds left)
# East: RED (Waiting: 8 seconds)
# South: RED (Waiting: 18 seconds)
# West: RED (Waiting: 28 seconds)
# Traffic Signal Status:
# North: GREEN (4 seconds left)
# East: RED (Waiting: 7 seconds)
# South: RED (Waiting: 17 seconds)
# West: RED (Waiting: 27 seconds)
# Traffic Signal Status:
# North: GREEN (3 seconds left)
# East: RED (Waiting: 6 seconds)
# South: RED (Waiting: 16 seconds)
# West: RED (Waiting: 26 seconds)
# Traffic Signal Status:
# North: GREEN (2 seconds left)
# East: RED (Waiting: 5 seconds)
# South: RED (Waiting: 15 seconds)
# West: RED (Waiting: 25 seconds)
# Traffic Signal Status:
# North: GREEN (1 seconds left)
# East: RED (Waiting: 4 seconds)
# South: RED (Waiting: 14 seconds)
# West: RED (Waiting: 24 seconds)
# Traffic Signal Status:
# North: ORANGE (3 seconds left)
# East: RED (Waiting: 3 seconds)
# South: RED (Waiting: 13 seconds)
# West: RED (Waiting: 23 seconds)
# Traffic Signal Status:
# North: ORANGE (2 seconds left)
# East: RED (Waiting: 2 seconds)
# South: RED (Waiting: 12 seconds)
# West: RED (Waiting: 22 seconds)
# Traffic Signal Status:
# North: ORANGE (1 seconds left)
# East: RED (Waiting: 1 seconds)
# South: RED (Waiting: 11 seconds)
# West: RED (Waiting: 21 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 33 seconds)
# East: GREEN (10 seconds left)
# South: RED (Waiting: 13 seconds)
# West: RED (Waiting: 23 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 32 seconds)
# East: GREEN (9 seconds left)
# South: RED (Waiting: 12 seconds)
# West: RED (Waiting: 22 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 31 seconds)
# East: GREEN (8 seconds left)
# South: RED (Waiting: 11 seconds)
# West: RED (Waiting: 21 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 30 seconds)
# East: GREEN (7 seconds left)
# South: RED (Waiting: 10 seconds)
# West: RED (Waiting: 20 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 29 seconds)
# East: GREEN (6 seconds left)
# South: RED (Waiting: 9 seconds)
# West: RED (Waiting: 19 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 28 seconds)
# East: GREEN (5 seconds left)
# South: RED (Waiting: 8 seconds)
# West: RED (Waiting: 18 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 27 seconds)
# East: GREEN (4 seconds left)
# South: RED (Waiting: 7 seconds)
# West: RED (Waiting: 17 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 26 seconds)
# East: GREEN (3 seconds left)
# South: RED (Waiting: 6 seconds)
# West: RED (Waiting: 16 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 25 seconds)
# East: GREEN (2 seconds left)
# South: RED (Waiting: 5 seconds)
# West: RED (Waiting: 15 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 24 seconds)
# East: GREEN (1 seconds left)
# South: RED (Waiting: 4 seconds)
# West: RED (Waiting: 14 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 23 seconds)
# East: ORANGE (3 seconds left)
# South: RED (Waiting: 3 seconds)
# West: RED (Waiting: 13 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 22 seconds)
# East: ORANGE (2 seconds left)
# South: RED (Waiting: 2 seconds)
# West: RED (Waiting: 12 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 21 seconds)
# East: ORANGE (1 seconds left)
# South: RED (Waiting: 1 seconds)
# West: RED (Waiting: 11 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 23 seconds)
# East: RED (Waiting: 33 seconds)
# South: GREEN (10 seconds left)
# West: RED (Waiting: 13 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 22 seconds)
# East: RED (Waiting: 32 seconds)
# South: GREEN (9 seconds left)
# West: RED (Waiting: 12 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 21 seconds)
# East: RED (Waiting: 31 seconds)
# South: GREEN (8 seconds left)
# West: RED (Waiting: 11 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 20 seconds)
# East: RED (Waiting: 30 seconds)
# South: GREEN (7 seconds left)
# West: RED (Waiting: 10 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 19 seconds)
# East: RED (Waiting: 29 seconds)
# South: GREEN (6 seconds left)
# West: RED (Waiting: 9 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 18 seconds)
# East: RED (Waiting: 28 seconds)
# South: GREEN (5 seconds left)
# West: RED (Waiting: 8 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 17 seconds)
# East: RED (Waiting: 27 seconds)
# South: GREEN (4 seconds left)
# West: RED (Waiting: 7 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 16 seconds)
# East: RED (Waiting: 26 seconds)
# South: GREEN (3 seconds left)
# West: RED (Waiting: 6 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 15 seconds)
# East: RED (Waiting: 25 seconds)
# South: GREEN (2 seconds left)
# West: RED (Waiting: 5 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 14 seconds)
# East: RED (Waiting: 24 seconds)
# South: GREEN (1 seconds left)
# West: RED (Waiting: 4 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 13 seconds)
# East: RED (Waiting: 23 seconds)
# South: ORANGE (3 seconds left)
# West: RED (Waiting: 3 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 12 seconds)
# East: RED (Waiting: 22 seconds)
# South: ORANGE (2 seconds left)
# West: RED (Waiting: 2 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 11 seconds)
# East: RED (Waiting: 21 seconds)
# South: ORANGE (1 seconds left)
# West: RED (Waiting: 1 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 13 seconds)
# East: RED (Waiting: 23 seconds)
# South: RED (Waiting: 33 seconds)
# West: GREEN (10 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 12 seconds)
# East: RED (Waiting: 22 seconds)
# South: RED (Waiting: 32 seconds)
# West: GREEN (9 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 11 seconds)
# East: RED (Waiting: 21 seconds)
# South: RED (Waiting: 31 seconds)
# West: GREEN (8 seconds left)
#
# Traffic signal simulation ended.

# %%
import time
import json

def load_traffic_data(file_path):
    """Load traffic signal data from a JSON file."""
    with open(file_path, 'r') as file:
        return json.load(file)

def traffic_signal(data):
    # Parse directions and their durations from the data
    directions = [
        {"name": direction, "green": info["Green"], "orange": info["Orange"]}
        for direction, info in data.items()
    ]

    while True:
        for i, direction in enumerate(directions):
            # Handle green signal
            for t in range(direction["green"], 0, -1):
                # Clear the console for dynamic updates (optional for better visualization)
                print("\033[H\033[J", end="")  # ANSI escape sequence to clear screen

                # Display the traffic signal status
                print("Traffic Signal Status:")
                for j, d in enumerate(directions):
                    if d["name"] == direction["name"]:
                        print(f"{d['name']}: GREEN ({t} seconds left)")
                    else:
                        # Calculate the waiting time based on the current position and the cycle
                        cycle_offset = (j - i - 1) % len(directions)
                        remaining_time = sum(
                            directions[(i + 1 + k) % len(directions)]["green"] + directions[(i + 1 + k) % len(directions)]["orange"]
                            for k in range(cycle_offset)
                        ) + direction["orange"]
                        print(f"{d['name']}: RED (Waiting: {remaining_time + t} seconds)")

                # Wait for 1 second
                time.sleep(1)

            # Handle orange signal
            for t in range(direction["orange"], 0, -1):
                # Clear the console for dynamic updates (optional for better visualization)
                print("\033[H\033[J", end="")  # ANSI escape sequence to clear screen

                # Display the traffic signal status
                print("Traffic Signal Status:")
                for j, d in enumerate(directions):
                    if d["name"] == direction["name"]:
                        print(f"{d['name']}: ORANGE ({t} seconds left)")
                    else:
                        # Calculate the waiting time based on the current position and the cycle
                        cycle_offset = (j - i - 1) % len(directions)
                        remaining_time = sum(
                            directions[(i + 1 + k) % len(directions)]["green"] + directions[(i + 1 + k) % len(directions)]["orange"]
                            for k in range(cycle_offset)
                        ) + direction["orange"]
                        print(f"{d['name']}: RED (Waiting: {remaining_time + t - direction['orange']} seconds)")

                # Wait for 1 second
                time.sleep(1)

if __name__ == "__main__":
    try:
        # Load traffic data from the JSON file
        traffic_data = load_traffic_data("../outputs/traffic_data.json")
        traffic_signal(traffic_data)
    except KeyboardInterrupt:
        print("\nTraffic signal simulation ended.")
    except FileNotFoundError:
        print("Error: traffic_data.json file not found.")
# Out:
# Traffic Signal Status:
# North: GREEN (71 seconds left)
# South: RED (Waiting: 74 seconds)
# East: RED (Waiting: 102 seconds)
# West: RED (Waiting: 113 seconds)
# Traffic Signal Status:
# North: GREEN (70 seconds left)
# South: RED (Waiting: 73 seconds)
# East: RED (Waiting: 101 seconds)
# West: RED (Waiting: 112 seconds)
# Traffic Signal Status:
# North: GREEN (69 seconds left)
# South: RED (Waiting: 72 seconds)
# East: RED (Waiting: 100 seconds)
# West: RED (Waiting: 111 seconds)
# Traffic Signal Status:
# North: GREEN (68 seconds left)
# South: RED (Waiting: 71 seconds)
# East: RED (Waiting: 99 seconds)
# West: RED (Waiting: 110 seconds)
# Traffic Signal Status:
# North: GREEN (67 seconds left)
# South: RED (Waiting: 70 seconds)
# East: RED (Waiting: 98 seconds)
# West: RED (Waiting: 109 seconds)
# Traffic Signal Status:
# North: GREEN (66 seconds left)
# South: RED (Waiting: 69 seconds)
# East: RED (Waiting: 97 seconds)
# West: RED (Waiting: 108 seconds)
# Traffic Signal Status:
# North: GREEN (65 seconds left)
# South: RED (Waiting: 68 seconds)
# East: RED (Waiting: 96 seconds)
# West: RED (Waiting: 107 seconds)
# Traffic Signal Status:
# North: GREEN (64 seconds left)
# South: RED (Waiting: 67 seconds)
# East: RED (Waiting: 95 seconds)
# West: RED (Waiting: 106 seconds)
# Traffic Signal Status:
# North: GREEN (63 seconds left)
# South: RED (Waiting: 66 seconds)
# East: RED (Waiting: 94 seconds)
# West: RED (Waiting: 105 seconds)
# Traffic Signal Status:
# North: GREEN (62 seconds left)
# South: RED (Waiting: 65 seconds)
# East: RED (Waiting: 93 seconds)
# West: RED (Waiting: 104 seconds)
# Traffic Signal Status:
# North: GREEN (61 seconds left)
# South: RED (Waiting: 64 seconds)
# East: RED (Waiting: 92 seconds)
# West: RED (Waiting: 103 seconds)
# Traffic Signal Status:
# North: GREEN (60 seconds left)
# South: RED (Waiting: 63 seconds)
# East: RED (Waiting: 91 seconds)
# West: RED (Waiting: 102 seconds)
# Traffic Signal Status:
# North: GREEN (59 seconds left)
# South: RED (Waiting: 62 seconds)
# East: RED (Waiting: 90 seconds)
# West: RED (Waiting: 101 seconds)
# Traffic Signal Status:
# North: GREEN (58 seconds left)
# South: RED (Waiting: 61 seconds)
# East: RED (Waiting: 89 seconds)
# West: RED (Waiting: 100 seconds)
# Traffic Signal Status:
# North: GREEN (57 seconds left)
# South: RED (Waiting: 60 seconds)
# East: RED (Waiting: 88 seconds)
# West: RED (Waiting: 99 seconds)
# Traffic Signal Status:
# North: GREEN (56 seconds left)
# South: RED (Waiting: 59 seconds)
# East: RED (Waiting: 87 seconds)
# West: RED (Waiting: 98 seconds)
# Traffic Signal Status:
# North: GREEN (55 seconds left)
# South: RED (Waiting: 58 seconds)
# East: RED (Waiting: 86 seconds)
# West: RED (Waiting: 97 seconds)
# Traffic Signal Status:
# North: GREEN (54 seconds left)
# South: RED (Waiting: 57 seconds)
# East: RED (Waiting: 85 seconds)
# West: RED (Waiting: 96 seconds)
# Traffic Signal Status:
# North: GREEN (53 seconds left)
# South: RED (Waiting: 56 seconds)
# East: RED (Waiting: 84 seconds)
# West: RED (Waiting: 95 seconds)
# Traffic Signal Status:
# North: GREEN (52 seconds left)
# South: RED (Waiting: 55 seconds)
# East: RED (Waiting: 83 seconds)
# West: RED (Waiting: 94 seconds)
# Traffic Signal Status:
# North: GREEN (51 seconds left)
# South: RED (Waiting: 54 seconds)
# East: RED (Waiting: 82 seconds)
# West: RED (Waiting: 93 seconds)
# Traffic Signal Status:
# North: GREEN (50 seconds left)
# South: RED (Waiting: 53 seconds)
# East: RED (Waiting: 81 seconds)
# West: RED (Waiting: 92 seconds)
# Traffic Signal Status:
# North: GREEN (49 seconds left)
# South: RED (Waiting: 52 seconds)
# East: RED (Waiting: 80 seconds)
# West: RED (Waiting: 91 seconds)
# Traffic Signal Status:
# North: GREEN (48 seconds left)
# South: RED (Waiting: 51 seconds)
# East: RED (Waiting: 79 seconds)
# West: RED (Waiting: 90 seconds)
# Traffic Signal Status:
# North: GREEN (47 seconds left)
# South: RED (Waiting: 50 seconds)
# East: RED (Waiting: 78 seconds)
# West: RED (Waiting: 89 seconds)
# Traffic Signal Status:
# North: GREEN (46 seconds left)
# South: RED (Waiting: 49 seconds)
# East: RED (Waiting: 77 seconds)
# West: RED (Waiting: 88 seconds)
# Traffic Signal Status:
# North: GREEN (45 seconds left)
# South: RED (Waiting: 48 seconds)
# East: RED (Waiting: 76 seconds)
# West: RED (Waiting: 87 seconds)
# Traffic Signal Status:
# North: GREEN (44 seconds left)
# South: RED (Waiting: 47 seconds)
# East: RED (Waiting: 75 seconds)
# West: RED (Waiting: 86 seconds)
# Traffic Signal Status:
# North: GREEN (43 seconds left)
# South: RED (Waiting: 46 seconds)
# East: RED (Waiting: 74 seconds)
# West: RED (Waiting: 85 seconds)
# Traffic Signal Status:
# North: GREEN (42 seconds left)
# South: RED (Waiting: 45 seconds)
# East: RED (Waiting: 73 seconds)
# West: RED (Waiting: 84 seconds)
# Traffic Signal Status:
# North: GREEN (41 seconds left)
# South: RED (Waiting: 44 seconds)
# East: RED (Waiting: 72 seconds)
# West: RED (Waiting: 83 seconds)
# Traffic Signal Status:
# North: GREEN (40 seconds left)
# South: RED (Waiting: 43 seconds)
# East: RED (Waiting: 71 seconds)
# West: RED (Waiting: 82 seconds)
# Traffic Signal Status:
# North: GREEN (39 seconds left)
# South: RED (Waiting: 42 seconds)
# East: RED (Waiting: 70 seconds)
# West: RED (Waiting: 81 seconds)
# Traffic Signal Status:
# North: GREEN (38 seconds left)
# South: RED (Waiting: 41 seconds)
# East: RED (Waiting: 69 seconds)
# West: RED (Waiting: 80 seconds)
# Traffic Signal Status:
# North: GREEN (37 seconds left)
# South: RED (Waiting: 40 seconds)
# East: RED (Waiting: 68 seconds)
# West: RED (Waiting: 79 seconds)
# Traffic Signal Status:
# North: GREEN (36 seconds left)
# South: RED (Waiting: 39 seconds)
# East: RED (Waiting: 67 seconds)
# West: RED (Waiting: 78 seconds)
# Traffic Signal Status:
# North: GREEN (35 seconds left)
# South: RED (Waiting: 38 seconds)
# East: RED (Waiting: 66 seconds)
# West: RED (Waiting: 77 seconds)
# Traffic Signal Status:
# North: GREEN (34 seconds left)
# South: RED (Waiting: 37 seconds)
# East: RED (Waiting: 65 seconds)
# West: RED (Waiting: 76 seconds)
# Traffic Signal Status:
# North: GREEN (33 seconds left)
# South: RED (Waiting: 36 seconds)
# East: RED (Waiting: 64 seconds)
# West: RED (Waiting: 75 seconds)
# Traffic Signal Status:
# North: GREEN (32 seconds left)
# South: RED (Waiting: 35 seconds)
# East: RED (Waiting: 63 seconds)
# West: RED (Waiting: 74 seconds)
# Traffic Signal Status:
# North: GREEN (31 seconds left)
# South: RED (Waiting: 34 seconds)
# East: RED (Waiting: 62 seconds)
# West: RED (Waiting: 73 seconds)
# Traffic Signal Status:
# North: GREEN (30 seconds left)
# South: RED (Waiting: 33 seconds)
# East: RED (Waiting: 61 seconds)
# West: RED (Waiting: 72 seconds)
# Traffic Signal Status:
# North: GREEN (29 seconds left)
# South: RED (Waiting: 32 seconds)
# East: RED (Waiting: 60 seconds)
# West: RED (Waiting: 71 seconds)
# Traffic Signal Status:
# North: GREEN (28 seconds left)
# South: RED (Waiting: 31 seconds)
# East: RED (Waiting: 59 seconds)
# West: RED (Waiting: 70 seconds)
# Traffic Signal Status:
# North: GREEN (27 seconds left)
# South: RED (Waiting: 30 seconds)
# East: RED (Waiting: 58 seconds)
# West: RED (Waiting: 69 seconds)
# Traffic Signal Status:
# North: GREEN (26 seconds left)
# South: RED (Waiting: 29 seconds)
# East: RED (Waiting: 57 seconds)
# West: RED (Waiting: 68 seconds)
# Traffic Signal Status:
# North: GREEN (25 seconds left)
# South: RED (Waiting: 28 seconds)
# East: RED (Waiting: 56 seconds)
# West: RED (Waiting: 67 seconds)
# Traffic Signal Status:
# North: GREEN (24 seconds left)
# South: RED (Waiting: 27 seconds)
# East: RED (Waiting: 55 seconds)
# West: RED (Waiting: 66 seconds)
# Traffic Signal Status:
# North: GREEN (23 seconds left)
# South: RED (Waiting: 26 seconds)
# East: RED (Waiting: 54 seconds)
# West: RED (Waiting: 65 seconds)
# Traffic Signal Status:
# North: GREEN (22 seconds left)
# South: RED (Waiting: 25 seconds)
# East: RED (Waiting: 53 seconds)
# West: RED (Waiting: 64 seconds)
# Traffic Signal Status:
# North: GREEN (21 seconds left)
# South: RED (Waiting: 24 seconds)
# East: RED (Waiting: 52 seconds)
# West: RED (Waiting: 63 seconds)
# Traffic Signal Status:
# North: GREEN (20 seconds left)
# South: RED (Waiting: 23 seconds)
# East: RED (Waiting: 51 seconds)
# West: RED (Waiting: 62 seconds)
# Traffic Signal Status:
# North: GREEN (19 seconds left)
# South: RED (Waiting: 22 seconds)
# East: RED (Waiting: 50 seconds)
# West: RED (Waiting: 61 seconds)
# Traffic Signal Status:
# North: GREEN (18 seconds left)
# South: RED (Waiting: 21 seconds)
# East: RED (Waiting: 49 seconds)
# West: RED (Waiting: 60 seconds)
# Traffic Signal Status:
# North: GREEN (17 seconds left)
# South: RED (Waiting: 20 seconds)
# East: RED (Waiting: 48 seconds)
# West: RED (Waiting: 59 seconds)
# Traffic Signal Status:
# North: GREEN (16 seconds left)
# South: RED (Waiting: 19 seconds)
# East: RED (Waiting: 47 seconds)
# West: RED (Waiting: 58 seconds)
# Traffic Signal Status:
# North: GREEN (15 seconds left)
# South: RED (Waiting: 18 seconds)
# East: RED (Waiting: 46 seconds)
# West: RED (Waiting: 57 seconds)
# Traffic Signal Status:
# North: GREEN (14 seconds left)
# South: RED (Waiting: 17 seconds)
# East: RED (Waiting: 45 seconds)
# West: RED (Waiting: 56 seconds)
# Traffic Signal Status:
# North: GREEN (13 seconds left)
# South: RED (Waiting: 16 seconds)
# East: RED (Waiting: 44 seconds)
# West: RED (Waiting: 55 seconds)
# Traffic Signal Status:
# North: GREEN (12 seconds left)
# South: RED (Waiting: 15 seconds)
# East: RED (Waiting: 43 seconds)
# West: RED (Waiting: 54 seconds)
# Traffic Signal Status:
# North: GREEN (11 seconds left)
# South: RED (Waiting: 14 seconds)
# East: RED (Waiting: 42 seconds)
# West: RED (Waiting: 53 seconds)
# Traffic Signal Status:
# North: GREEN (10 seconds left)
# South: RED (Waiting: 13 seconds)
# East: RED (Waiting: 41 seconds)
# West: RED (Waiting: 52 seconds)
# Traffic Signal Status:
# North: GREEN (9 seconds left)
# South: RED (Waiting: 12 seconds)
# East: RED (Waiting: 40 seconds)
# West: RED (Waiting: 51 seconds)
# Traffic Signal Status:
# North: GREEN (8 seconds left)
# South: RED (Waiting: 11 seconds)
# East: RED (Waiting: 39 seconds)
# West: RED (Waiting: 50 seconds)
# Traffic Signal Status:
# North: GREEN (7 seconds left)
# South: RED (Waiting: 10 seconds)
# East: RED (Waiting: 38 seconds)
# West: RED (Waiting: 49 seconds)
# Traffic Signal Status:
# North: GREEN (6 seconds left)
# South: RED (Waiting: 9 seconds)
# East: RED (Waiting: 37 seconds)
# West: RED (Waiting: 48 seconds)
# Traffic Signal Status:
# North: GREEN (5 seconds left)
# South: RED (Waiting: 8 seconds)
# East: RED (Waiting: 36 seconds)
# West: RED (Waiting: 47 seconds)
# Traffic Signal Status:
# North: GREEN (4 seconds left)
# South: RED (Waiting: 7 seconds)
# East: RED (Waiting: 35 seconds)
# West: RED (Waiting: 46 seconds)
# Traffic Signal Status:
# North: GREEN (3 seconds left)
# South: RED (Waiting: 6 seconds)
# East: RED (Waiting: 34 seconds)
# West: RED (Waiting: 45 seconds)
# Traffic Signal Status:
# North: GREEN (2 seconds left)
# South: RED (Waiting: 5 seconds)
# East: RED (Waiting: 33 seconds)
# West: RED (Waiting: 44 seconds)
# Traffic Signal Status:
# North: GREEN (1 seconds left)
# South: RED (Waiting: 4 seconds)
# East: RED (Waiting: 32 seconds)
# West: RED (Waiting: 43 seconds)
# Traffic Signal Status:
# North: ORANGE (3 seconds left)
# South: RED (Waiting: 3 seconds)
# East: RED (Waiting: 31 seconds)
# West: RED (Waiting: 42 seconds)
# Traffic Signal Status:
# North: ORANGE (2 seconds left)
# South: RED (Waiting: 2 seconds)
# East: RED (Waiting: 30 seconds)
# West: RED (Waiting: 41 seconds)
# Traffic Signal Status:
# North: ORANGE (1 seconds left)
# South: RED (Waiting: 1 seconds)
# East: RED (Waiting: 29 seconds)
# West: RED (Waiting: 40 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 45 seconds)
# South: GREEN (25 seconds left)
# East: RED (Waiting: 28 seconds)
# West: RED (Waiting: 39 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 44 seconds)
# South: GREEN (24 seconds left)
# East: RED (Waiting: 27 seconds)
# West: RED (Waiting: 38 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 43 seconds)
# South: GREEN (23 seconds left)
# East: RED (Waiting: 26 seconds)
# West: RED (Waiting: 37 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 42 seconds)
# South: GREEN (22 seconds left)
# East: RED (Waiting: 25 seconds)
# West: RED (Waiting: 36 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 41 seconds)
# South: GREEN (21 seconds left)
# East: RED (Waiting: 24 seconds)
# West: RED (Waiting: 35 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 40 seconds)
# South: GREEN (20 seconds left)
# East: RED (Waiting: 23 seconds)
# West: RED (Waiting: 34 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 39 seconds)
# South: GREEN (19 seconds left)
# East: RED (Waiting: 22 seconds)
# West: RED (Waiting: 33 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 38 seconds)
# South: GREEN (18 seconds left)
# East: RED (Waiting: 21 seconds)
# West: RED (Waiting: 32 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 37 seconds)
# South: GREEN (17 seconds left)
# East: RED (Waiting: 20 seconds)
# West: RED (Waiting: 31 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 36 seconds)
# South: GREEN (16 seconds left)
# East: RED (Waiting: 19 seconds)
# West: RED (Waiting: 30 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 35 seconds)
# South: GREEN (15 seconds left)
# East: RED (Waiting: 18 seconds)
# West: RED (Waiting: 29 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 34 seconds)
# South: GREEN (14 seconds left)
# East: RED (Waiting: 17 seconds)
# West: RED (Waiting: 28 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 33 seconds)
# South: GREEN (13 seconds left)
# East: RED (Waiting: 16 seconds)
# West: RED (Waiting: 27 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 32 seconds)
# South: GREEN (12 seconds left)
# East: RED (Waiting: 15 seconds)
# West: RED (Waiting: 26 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 31 seconds)
# South: GREEN (11 seconds left)
# East: RED (Waiting: 14 seconds)
# West: RED (Waiting: 25 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 30 seconds)
# South: GREEN (10 seconds left)
# East: RED (Waiting: 13 seconds)
# West: RED (Waiting: 24 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 29 seconds)
# South: GREEN (9 seconds left)
# East: RED (Waiting: 12 seconds)
# West: RED (Waiting: 23 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 28 seconds)
# South: GREEN (8 seconds left)
# East: RED (Waiting: 11 seconds)
# West: RED (Waiting: 22 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 27 seconds)
# South: GREEN (7 seconds left)
# East: RED (Waiting: 10 seconds)
# West: RED (Waiting: 21 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 26 seconds)
# South: GREEN (6 seconds left)
# East: RED (Waiting: 9 seconds)
# West: RED (Waiting: 20 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 25 seconds)
# South: GREEN (5 seconds left)
# East: RED (Waiting: 8 seconds)
# West: RED (Waiting: 19 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 24 seconds)
# South: GREEN (4 seconds left)
# East: RED (Waiting: 7 seconds)
# West: RED (Waiting: 18 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 23 seconds)
# South: GREEN (3 seconds left)
# East: RED (Waiting: 6 seconds)
# West: RED (Waiting: 17 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 22 seconds)
# South: GREEN (2 seconds left)
# East: RED (Waiting: 5 seconds)
# West: RED (Waiting: 16 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 21 seconds)
# South: GREEN (1 seconds left)
# East: RED (Waiting: 4 seconds)
# West: RED (Waiting: 15 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 20 seconds)
# South: ORANGE (3 seconds left)
# East: RED (Waiting: 3 seconds)
# West: RED (Waiting: 14 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 19 seconds)
# South: ORANGE (2 seconds left)
# East: RED (Waiting: 2 seconds)
# West: RED (Waiting: 13 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 18 seconds)
# South: ORANGE (1 seconds left)
# East: RED (Waiting: 1 seconds)
# West: RED (Waiting: 12 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 17 seconds)
# South: RED (Waiting: 91 seconds)
# East: GREEN (8 seconds left)
# West: RED (Waiting: 11 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 16 seconds)
# South: RED (Waiting: 90 seconds)
# East: GREEN (7 seconds left)
# West: RED (Waiting: 10 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 15 seconds)
# South: RED (Waiting: 89 seconds)
# East: GREEN (6 seconds left)
# West: RED (Waiting: 9 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 14 seconds)
# South: RED (Waiting: 88 seconds)
# East: GREEN (5 seconds left)
# West: RED (Waiting: 8 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 13 seconds)
# South: RED (Waiting: 87 seconds)
# East: GREEN (4 seconds left)
# West: RED (Waiting: 7 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 12 seconds)
# South: RED (Waiting: 86 seconds)
# East: GREEN (3 seconds left)
# West: RED (Waiting: 6 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 11 seconds)
# South: RED (Waiting: 85 seconds)
# East: GREEN (2 seconds left)
# West: RED (Waiting: 5 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 10 seconds)
# South: RED (Waiting: 84 seconds)
# East: GREEN (1 seconds left)
# West: RED (Waiting: 4 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 9 seconds)
# South: RED (Waiting: 83 seconds)
# East: ORANGE (3 seconds left)
# West: RED (Waiting: 3 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 8 seconds)
# South: RED (Waiting: 82 seconds)
# East: ORANGE (2 seconds left)
# West: RED (Waiting: 2 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 7 seconds)
# South: RED (Waiting: 81 seconds)
# East: ORANGE (1 seconds left)
# West: RED (Waiting: 1 seconds)
# Traffic Signal Status:
# North: RED (Waiting: 6 seconds)
# South: RED (Waiting: 80 seconds)
# East: RED (Waiting: 108 seconds)
# West: GREEN (3 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 5 seconds)
# South: RED (Waiting: 79 seconds)
# East: RED (Waiting: 107 seconds)
# West: GREEN (2 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 4 seconds)
# South: RED (Waiting: 78 seconds)
# East: RED (Waiting: 106 seconds)
# West: GREEN (1 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 3 seconds)
# South: RED (Waiting: 77 seconds)
# East: RED (Waiting: 105 seconds)
# West: ORANGE (3 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 2 seconds)
# South: RED (Waiting: 76 seconds)
# East: RED (Waiting: 104 seconds)
# West: ORANGE (2 seconds left)
# Traffic Signal Status:
# North: RED (Waiting: 1 seconds)
# South: RED (Waiting: 75 seconds)
# East: RED (Waiting: 103 seconds)
# West: ORANGE (1 seconds left)
# Traffic Signal Status:
# North: GREEN (71 seconds left)
# South: RED (Waiting: 74 seconds)
# East: RED (Waiting: 102 seconds)
# West: RED (Waiting: 113 seconds)
# Traffic Signal Status:
# North: GREEN (70 seconds left)
# South: RED (Waiting: 73 seconds)
# East: RED (Waiting: 101 seconds)
# West: RED (Waiting: 112 seconds)
# Traffic Signal Status:
# North: GREEN (69 seconds left)
# South: RED (Waiting: 72 seconds)
# East: RED (Waiting: 100 seconds)
# West: RED (Waiting: 111 seconds)
# Traffic Signal Status:
# North: GREEN (68 seconds left)
# South: RED (Waiting: 71 seconds)
# East: RED (Waiting: 99 seconds)
# West: RED (Waiting: 110 seconds)
# Traffic Signal Status:
# North: GREEN (67 seconds left)
# South: RED (Waiting: 70 seconds)
# East: RED (Waiting: 98 seconds)
# West: RED (Waiting: 109 seconds)
# Traffic Signal Status:
# North: GREEN (66 seconds left)
# South: RED (Waiting: 69 seconds)
# East: RED (Waiting: 97 seconds)
# West: RED (Waiting: 108 seconds)
# Traffic Signal Status:
# North: GREEN (65 seconds left)
# South: RED (Waiting: 68 seconds)
# East: RED (Waiting: 96 seconds)
# West: RED (Waiting: 107 seconds)
#
# Traffic signal simulation ended.
